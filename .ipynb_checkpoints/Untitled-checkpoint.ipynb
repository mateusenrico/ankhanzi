# %%
import pandas as pd

# %%
pd.read_json("./static/out/List-DICT.json")
# Out:
#        traditional simplified  \
# 0              喀布爾        喀布尔
# 1               閱兵         阅兵
# 2              波茲南        波兹南
# 3             一式二份       一式二份
# 4             無頭蒼蠅       无头苍蝇
# ...            ...        ...
# 118613           澈          澈
# 118614          賀縣         贺县
# 118615          發奮         发奋
# 118616          籌算         筹算
# 118617          俄烏         俄乌
#
#                                                   entries
# 0       [{'pinyin': 'Ka1 bu4 er3', 'definition': ['Kab...
# 1       [{'pinyin': 'yue4 bing1', 'definition': ['to r...
# 2       [{'pinyin': 'Bo1 zi1 nan2', 'definition': ['Po...
# 3       [{'pinyin': 'yi1 shi4 er2 fen4', 'definition':...
# 4       [{'pinyin': 'wu2 tou2 cang1 ying5', 'definitio...
# ...                                                   ...
# 118613  [{'pinyin': 'che4', 'definition': ['clear (wat...
# 118614  [{'pinyin': 'He4 xian4', 'definition': ['He co...
# 118615  [{'pinyin': 'fa1 fen4', 'definition': ['to mak...
# ...
